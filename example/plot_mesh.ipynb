# %%
import cascadoc
import matplotlib.pyplot as plt
block = cascadoc.HypBlock({'C':[2.001, 0.599], 'S': [0, 1], 'T': [0, 1.5], 'h':0.1})

# %%
plt.figure(dpi=300)
block.build_mesh()
block.plot_mesh()
# plt.yticks([0.25+0.0125*i for i in range(10)])
# plt.xticks([0.5+0.05*i for i in range(-10, 10) ],rotation=90)
# plt.grid()

# plt.xlim([0.4, 0.9])
# plt.ylim([0.15, 0.35])
# Out:
# (np.float64(0.5), np.float64(0.75))
